# %%
import os
print(os.listdir("files"))
# Out:
# ['supermarkets-commas.txt', 'supermarkets-semi-colons.txt', 'supermarkets.csv', 'supermarkets.json', 'supermarkets.xlsx']

# %%
import pandas

# %%
df1 = pandas.read_csv("files/supermarkets.csv")
df1
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df2 = pandas.read_json("files/supermarkets.json")
df2
# Out:
#            Address           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State
# 0          CA 94114
# 1          CA 94119
# 2  California 94114
# 3          CA 94114
# 4        California
# 5          CA 94114

# %%
df3 = pandas.read_excel("files/supermarkets.xlsx", sheet_name = 0)
df3
# Out:
#    ID          Address           City             State Country  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees
# 0          Madeira                    8
# 1      Bready Shop                   15
# 2      Super River                   25
# 3       Ben's Shop                   10
# 4          Sanchez                   12
# 5       Richvalley                   20

# %%
df4 = pandas.read_csv("files/supermarkets-commas.txt")
df4
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df5 = pandas.read_csv("files/supermarkets-semi-colons.txt")
df5
#pandas.read_csv does not recognize ";" as a separator/delimiter
# Out:
#         ID;Address;City;State;Country;Name;Employees
# 0  1;3666 21st St;San Francisco;CA 94114;USA;Made...
# 1  2;735 Dolores St;San Francisco;CA 94119;USA;Br...
# 2  3;332 Hill St;San Francisco;California 94114;U...
# 3  4;3995 23rd St;San Francisco;CA 94114;USA;Ben'...
# 4  5;1056 Sanchez St;San Francisco;California;USA...
# 5  6;551 Alvarado St;San Francisco;CA 94114;USA;R...

# %%
df5 = pandas.read_csv("files/supermarkets-semi-colons.txt", separator = ";")
df5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-1d620bbd4573> in <module>
# ----> 1 df5 = pandas.read_csv("files/supermarkets-semi-colons.txt", separator = ";")
#       2 df5
#
# TypeError: parser_f() got an unexpected keyword argument 'separator'

# %%
# ask for help
pandas.read_csv?

# %%
df5 = pandas.read_csv("files/supermarkets-semi-colons.txt", sep = ";") #default delimiter is ','
df5
# Out:
#    ID          Address           City             State Country          Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA       Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df6 = pandas.read_csv("files/data.txt", header = None)
df6
# Out:
#    0                1              2                 3    4            5   6
# 0  1     3666 21st St  San Francisco          CA 94114  USA      Madeira   8
# 1  2   735 Dolores St  San Francisco          CA 94119  USA  Bready Shop  15
# 2  3      332 Hill St  San Francisco  California 94114  USA  Super River  25
# 3  4     3995 23rd St  San Francisco          CA 94114  USA   Ben's Shop  10
# 4  5  1056 Sanchez St  San Francisco        California  USA      Sanchez  12
# 5  6  551 Alvarado St  San Francisco          CA 94114  USA   Richvalley  20

# %%
df6.columns=["ID(col1)", "Address(col2)", "City(col3)", "Zip(col4)", "Country(col5)", "Name(col6)", "Employees(col7)"]
df6
# Out:
#    ID(col1)    Address(col2)     City(col3)         Zip(col4) Country(col5)  \
# 0         1     3666 21st St  San Francisco          CA 94114           USA
# 1         2   735 Dolores St  San Francisco          CA 94119           USA
# 2         3      332 Hill St  San Francisco  California 94114           USA
# 3         4     3995 23rd St  San Francisco          CA 94114           USA
# 4         5  1056 Sanchez St  San Francisco        California           USA
# 5         6  551 Alvarado St  San Francisco          CA 94114           USA
#
#     Name(col6)  Employees(col7)
# 0      Madeira                8
# 1  Bready Shop               15
# 2  Super River               25
# 3   Ben's Shop               10
# 4      Sanchez               12
# 5   Richvalley               20

# %%
df6.set_index("ID(col1)") #this method produces a new data frame on the fly, the original df6 will remain the same
# Out:
#             Address(col2)     City(col3)         Zip(col4) Country(col5)  \
# ID(col1)
# 1            3666 21st St  San Francisco          CA 94114           USA
# 2          735 Dolores St  San Francisco          CA 94119           USA
# 3             332 Hill St  San Francisco  California 94114           USA
# 4            3995 23rd St  San Francisco          CA 94114           USA
# 5         1056 Sanchez St  San Francisco        California           USA
# 6         551 Alvarado St  San Francisco          CA 94114           USA
#
#            Name(col6)  Employees(col7)
# ID(col1)
# 1             Madeira                8
# 2         Bready Shop               15
# 3         Super River               25
# 4          Ben's Shop               10
# 5             Sanchez               12
# 6          Richvalley               20

# %%
df6
# Out:
#    ID(col1)    Address(col2)     City(col3)         Zip(col4) Country(col5)  \
# 0         1     3666 21st St  San Francisco          CA 94114           USA
# 1         2   735 Dolores St  San Francisco          CA 94119           USA
# 2         3      332 Hill St  San Francisco  California 94114           USA
# 3         4     3995 23rd St  San Francisco          CA 94114           USA
# 4         5  1056 Sanchez St  San Francisco        California           USA
# 5         6  551 Alvarado St  San Francisco          CA 94114           USA
#
#     Name(col6)  Employees(col7)
# 0      Madeira                8
# 1  Bready Shop               15
# 2  Super River               25
# 3   Ben's Shop               10
# 4      Sanchez               12
# 5   Richvalley               20

# %%
df7 = df6.set_index("ID(col1)")
df7
# Out:
#             Address(col2)     City(col3)         Zip(col4) Country(col5)  \
# ID(col1)
# 1            3666 21st St  San Francisco          CA 94114           USA
# 2          735 Dolores St  San Francisco          CA 94119           USA
# 3             332 Hill St  San Francisco  California 94114           USA
# 4            3995 23rd St  San Francisco          CA 94114           USA
# 5         1056 Sanchez St  San Francisco        California           USA
# 6         551 Alvarado St  San Francisco          CA 94114           USA
#
#            Name(col6)  Employees(col7)
# ID(col1)
# 1             Madeira                8
# 2         Bready Shop               15
# 3         Super River               25
# 4          Ben's Shop               10
# 5             Sanchez               12
# 6          Richvalley               20

# %%
df8 = pandas.read_csv("files/data.txt")
df8
# Out:
#    1     3666 21st St  San Francisco          CA 94114  USA      Madeira   8
# 0  2   735 Dolores St  San Francisco          CA 94119  USA  Bready Shop  15
# 1  3      332 Hill St  San Francisco  California 94114  USA  Super River  25
# 2  4     3995 23rd St  San Francisco          CA 94114  USA   Ben's Shop  10
# 3  5  1056 Sanchez St  San Francisco        California  USA      Sanchez  12
# 4  6  551 Alvarado St  San Francisco          CA 94114  USA   Richvalley  20

# %%
df8.columns = ["ID(col1)", "Address(col2)", "City(col3)", "Zip(col4)", "Country(col5)", "Name(col6)", "Employees(col7)"]
df8
# Out:
#    ID(col1)    Address(col2)     City(col3)         Zip(col4) Country(col5)  \
# 0         2   735 Dolores St  San Francisco          CA 94119           USA
# 1         3      332 Hill St  San Francisco  California 94114           USA
# 2         4     3995 23rd St  San Francisco          CA 94114           USA
# 3         5  1056 Sanchez St  San Francisco        California           USA
# 4         6  551 Alvarado St  San Francisco          CA 94114           USA
#
#     Name(col6)  Employees(col7)
# 0  Bready Shop               15
# 1  Super River               25
# 2   Ben's Shop               10
# 3      Sanchez               12
# 4   Richvalley               20

# %%
df8.set_index("ID(col1)", inplace=True)

# %%
df8
# Out:
#             Address(col2)     City(col3)         Zip(col4) Country(col5)  \
# ID(col1)
# 2          735 Dolores St  San Francisco          CA 94119           USA
# 3             332 Hill St  San Francisco  California 94114           USA
# 4            3995 23rd St  San Francisco          CA 94114           USA
# 5         1056 Sanchez St  San Francisco        California           USA
# 6         551 Alvarado St  San Francisco          CA 94114           USA
#
#            Name(col6)  Employees(col7)
# ID(col1)
# 2         Bready Shop               15
# 3         Super River               25
# 4          Ben's Shop               10
# 5             Sanchez               12
# 6          Richvalley               20

# %%
df8.set_index("Address(col2)", inplace=True) #will put the address as the ID for column but the former ID(ID(col1)) will be erased
df8
# Out:
#                     City(col3)         Zip(col4) Country(col5)   Name(col6)  \
# Address(col2)
# 735 Dolores St   San Francisco          CA 94119           USA  Bready Shop
# 332 Hill St      San Francisco  California 94114           USA  Super River
# 3995 23rd St     San Francisco          CA 94114           USA   Ben's Shop
# 1056 Sanchez St  San Francisco        California           USA      Sanchez
# 551 Alvarado St  San Francisco          CA 94114           USA   Richvalley
#
#                  Employees(col7)
# Address(col2)
# 735 Dolores St                15
# 332 Hill St                   25
# 3995 23rd St                  10
# 1056 Sanchez St               12
# 551 Alvarado St               20

# %%
df8.set_index("Name(col6)", inplace=True, drop=False) #Here the name will be kept as a column even though it is used as index, however the Address index is dropped
df8
# Out:
#                 City(col3)         Zip(col4) Country(col5)   Name(col6)  \
# Name(col6)
# Bready Shop  San Francisco          CA 94119           USA  Bready Shop
# Super River  San Francisco  California 94114           USA  Super River
# Ben's Shop   San Francisco          CA 94114           USA   Ben's Shop
# Sanchez      San Francisco        California           USA      Sanchez
# Richvalley   San Francisco          CA 94114           USA   Richvalley
#
#              Employees(col7)
# Name(col6)
# Bready Shop               15
# Super River               25
# Ben's Shop                10
# Sanchez                   12
# Richvalley                20
